# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('data.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('texts.pkl','wb'))
pickle.dump(classes,open('labels.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model.h5', hist)

print("model created")
# Out:
# 79 documents
# 19 classes ['chemical_engineering', 'civil_engineering', 'data_preprocessing', 'data_science_overview', 'data_science_tools', 'data_visualization', 'deep_learning', 'electrical_engineering', 'engineering_calculations', 'engineering_disciplines', 'engineering_software_tools', 'goodbye', 'greeting', 'machine_learning', 'mechanical_engineering', 'noanswer', 'software_engineering', 'statistics', 'thanks']
# 95 unique lemmatized words ["'re", 'a', 'about', 'analysis', 'application', 'appreciate', 'are', 'basic', 'branch', 'bye', 'calculation', 'can', 'chemical', 'civil', 'clarify', 'cleaning', 'common', 'concept', 'data', 'deep', 'design', 'different', 'discipline', 'do', 'doe', 'electrical', 'engineer', 'engineering', 'example', 'explain', 'farewell', 'field', 'for', 'formula', 'further', 'goodbye', 'greeting', 'hello', 'helpful', 'hey', 'hi', 'how', 'i', 'importance', 'important', 'in', 'involve', 'is', 'it', 'later', 'learning', 'lot', 'machine', 'main', 'me', 'mean', 'mechanical', 'method', "n't", 'not', 'of', 'overview', 'perform', 'popular', 'practice', 'preprocessing', 'problem', 'process', 'project', 'role', 'science', 'scientist', 'see', 'software', 'statistic', 'statistical', 'step', 'sure', 'talk', 'technique', 'tell', 'thank', 'thanks', 'the', 'there', 'to', 'tool', 'type', 'understand', 'used', 'v', 'visualization', 'what', 'why', 'you']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 73
#      71 # shuffle our features and turn into np.array
#      72 random.shuffle(training)
# ---> 73 training = np.array(training)
#      74 # create train and test lists. X - patterns, Y - intents
#      75 train_x = list(training[:,0])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (79, 2) + inhomogeneous part.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import SGD
import random

# Load data
data_file = open('data.json').read()
intents = json.loads(data_file)

words = []
classes = []
documents = []
ignore_words = ['?', '!']

# Process intents
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lemmatize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)

# Save words and classes
pickle.dump(words, open('texts.pkl', 'wb'))
pickle.dump(classes, open('labels.pkl', 'wb'))

# Create training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# Debugging print to check lengths of input and output vectors
for t in training:
    print(f'Input vector length: {len(t[0])}, Output vector length: {len(t[1])}')

# Shuffle the training data
random.shuffle(training)

# Ensure all lists in training data have consistent lengths before converting to numpy arrays
train_x = []
train_y = []
for t in training:
    train_x.append(t[0])
    train_y.append(t[1])

# Convert lists to numpy arrays
train_x = np.array(train_x)
train_y = np.array(train_y)

print("Training data created")

# Create the model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile the model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Fit and save the model
hist = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)
model.save('model.h5', hist)

print("model created")
# Out:
# 79 documents
# 19 classes ['chemical_engineering', 'civil_engineering', 'data_preprocessing', 'data_science_overview', 'data_science_tools', 'data_visualization', 'deep_learning', 'electrical_engineering', 'engineering_calculations', 'engineering_disciplines', 'engineering_software_tools', 'goodbye', 'greeting', 'machine_learning', 'mechanical_engineering', 'noanswer', 'software_engineering', 'statistics', 'thanks']
# 95 unique lemmatized words ["'re", 'a', 'about', 'analysis', 'application', 'appreciate', 'are', 'basic', 'branch', 'bye', 'calculation', 'can', 'chemical', 'civil', 'clarify', 'cleaning', 'common', 'concept', 'data', 'deep', 'design', 'different', 'discipline', 'do', 'doe', 'electrical', 'engineer', 'engineering', 'example', 'explain', 'farewell', 'field', 'for', 'formula', 'further', 'goodbye', 'greeting', 'hello', 'helpful', 'hey', 'hi', 'how', 'i', 'importance', 'important', 'in', 'involve', 'is', 'it', 'later', 'learning', 'lot', 'machine', 'main', 'me', 'mean', 'mechanical', 'method', "n't", 'not', 'of', 'overview', 'perform', 'popular', 'practice', 'preprocessing', 'problem', 'process', 'project', 'role', 'science', 'scientist', 'see', 'software', 'statistic', 'statistical', 'step', 'sure', 'talk', 'technique', 'tell', 'thank', 'thanks', 'the', 'there', 'to', 'tool', 'type', 'understand', 'used', 'v', 'visualization', 'what', 'why', 'you']
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Training data created
# C:\Users\Windows\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Windows\anaconda3\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0195 - loss: 3.0087
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1171 - loss: 2.9473
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0625 - loss: 2.8687
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1120 - loss: 2.8563
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1171 - loss: 2.7938
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3211 - loss: 2.5570
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3144 - loss: 2.5688
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3434 - loss: 2.3597
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3227 - loss: 2.2284
# Epoch 10/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3754 - loss: 2.0555
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3663 - loss: 2.0143
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6128 - loss: 1.7581
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3765 - loss: 1.7192
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5407 - loss: 1.6427
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4837 - loss: 1.6818
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6190 - loss: 1.3168
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4877 - loss: 1.3118
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6364 - loss: 1.1929
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6701 - loss: 1.0597
# Epoch 20/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7789 - loss: 0.9192
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8254 - loss: 0.8002
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7668 - loss: 0.8526
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7352 - loss: 0.9080
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7667 - loss: 0.9399
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7446 - loss: 0.7798
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8037 - loss: 0.6450
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7638 - loss: 0.7915
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8813 - loss: 0.6420
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7179 - loss: 0.7494
# Epoch 30/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9096 - loss: 0.4580
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7829 - loss: 0.6941
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.3987
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9008 - loss: 0.4350
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8454 - loss: 0.5568
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9415 - loss: 0.3091
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7186 - loss: 0.6472
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7987 - loss: 0.4945
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8644 - loss: 0.4598
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.6806
# Epoch 40/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8463 - loss: 0.4608
# Epoch 41/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.3160
# Epoch 42/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9093 - loss: 0.3533
# Epoch 43/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7839 - loss: 0.5186
# Epoch 44/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.2401
# Epoch 45/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9262 - loss: 0.2562
# Epoch 46/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9467 - loss: 0.2695
# Epoch 47/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8864 - loss: 0.3247
# Epoch 48/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8602 - loss: 0.2540
# Epoch 49/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9150 - loss: 0.3142
# Epoch 50/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9267 - loss: 0.2943
# Epoch 51/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9208 - loss: 0.2888
# Epoch 52/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9458 - loss: 0.2340
# Epoch 53/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9388 - loss: 0.2219
# Epoch 54/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9850 - loss: 0.1883
# Epoch 55/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8889 - loss: 0.3058
# Epoch 56/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9503 - loss: 0.1601
# Epoch 57/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9513 - loss: 0.1824
# Epoch 58/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9553 - loss: 0.2184
# Epoch 59/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9794 - loss: 0.1227
# Epoch 60/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0665
# Epoch 61/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8843 - loss: 0.2659
# Epoch 62/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9242 - loss: 0.2627
# Epoch 63/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9599 - loss: 0.2567
# Epoch 64/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9977 - loss: 0.1572
# Epoch 65/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9648 - loss: 0.1169
# Epoch 66/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9597 - loss: 0.1439
# Epoch 67/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.1402
# Epoch 68/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9603 - loss: 0.1571
# Epoch 69/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9570 - loss: 0.1826
# Epoch 70/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.1098
# Epoch 71/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9447 - loss: 0.1523
# Epoch 72/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.2226
# Epoch 73/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9610 - loss: 0.1485
# Epoch 74/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8882 - loss: 0.3055
# Epoch 75/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9193 - loss: 0.1378
# Epoch 76/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9960 - loss: 0.1364
# Epoch 77/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9677 - loss: 0.1002
# Epoch 78/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0681
# Epoch 79/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9779 - loss: 0.1409
# Epoch 80/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9855 - loss: 0.1818
# Epoch 81/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0963
# Epoch 82/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.1301
# Epoch 83/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9670 - loss: 0.1189
# Epoch 84/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9537 - loss: 0.1791
# Epoch 85/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9365 - loss: 0.1883
# Epoch 86/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9215 - loss: 0.1787
# Epoch 87/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9792 - loss: 0.0926
# Epoch 88/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9817 - loss: 0.0674
# Epoch 89/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0747
# Epoch 90/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9638 - loss: 0.1697
# Epoch 91/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9771 - loss: 0.0795
# Epoch 92/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0671
# Epoch 93/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0726
# Epoch 94/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9712 - loss: 0.0802
# Epoch 95/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0883
# Epoch 96/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9480 - loss: 0.1386
# Epoch 97/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0678
# Epoch 98/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9555 - loss: 0.2094
# Epoch 99/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9630 - loss: 0.1243
# Epoch 100/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.0995
# Epoch 101/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9530 - loss: 0.1830
# Epoch 102/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.0878
# Epoch 103/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0929
# Epoch 104/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9215 - loss: 0.2342
# Epoch 105/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0644
# Epoch 106/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9883 - loss: 0.0519
# Epoch 107/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9407 - loss: 0.1495
# Epoch 108/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.3255
# Epoch 109/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9322 - loss: 0.2244
# Epoch 110/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0689
# Epoch 111/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.1749
# Epoch 112/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0790
# Epoch 113/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9746 - loss: 0.1107
# Epoch 114/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.1122
# Epoch 115/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0780
# Epoch 116/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9686 - loss: 0.1413
# Epoch 117/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.1702
# Epoch 118/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9335 - loss: 0.3020
# Epoch 119/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9939 - loss: 0.1090
# Epoch 120/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0373
# Epoch 121/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1310
# Epoch 122/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0599
# Epoch 123/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0305
# Epoch 124/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9534 - loss: 0.1192
# Epoch 125/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0701
# Epoch 126/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 127/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.0717
# Epoch 128/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9763 - loss: 0.0717
# Epoch 129/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0329
# Epoch 130/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9552 - loss: 0.1067
# Epoch 131/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9772 - loss: 0.0852
# Epoch 132/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9883 - loss: 0.0603
# Epoch 133/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9205 - loss: 0.1307
# Epoch 134/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0444
# Epoch 135/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0568
# Epoch 136/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.1174
# Epoch 137/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.0981
# Epoch 138/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0405
# Epoch 139/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9945 - loss: 0.0676
# Epoch 140/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9883 - loss: 0.0401
# Epoch 141/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9731 - loss: 0.0876
# Epoch 142/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9396 - loss: 0.0946
# Epoch 143/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9712 - loss: 0.1045
# Epoch 144/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0615
# Epoch 145/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9555 - loss: 0.0846
# Epoch 146/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0812
# Epoch 147/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9680 - loss: 0.1364
# Epoch 148/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9612 - loss: 0.0950
# Epoch 149/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9756 - loss: 0.1133
# Epoch 150/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0384
# Epoch 151/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0384
# Epoch 152/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0421
# Epoch 153/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9810 - loss: 0.0624
# Epoch 154/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9484 - loss: 0.1407
# Epoch 155/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9573 - loss: 0.0767
# Epoch 156/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0707
# Epoch 157/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9852 - loss: 0.0332
# Epoch 158/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9501 - loss: 0.0928
# Epoch 159/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0418
# Epoch 160/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0219
# Epoch 161/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9555 - loss: 0.1085
# Epoch 162/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0620
# Epoch 163/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0955
# Epoch 164/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9840 - loss: 0.0364
# Epoch 165/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0.0671
# Epoch 166/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0255
# Epoch 167/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.1019
# Epoch 168/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0714
# Epoch 169/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9839 - loss: 0.0563
# Epoch 170/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9823 - loss: 0.1101
# Epoch 171/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0289
# Epoch 172/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 173/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9595 - loss: 0.1055
# Epoch 174/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0507
# Epoch 175/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.1000
# Epoch 176/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9405 - loss: 0.1484
# Epoch 177/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9681 - loss: 0.0994
# Epoch 178/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0454
# Epoch 179/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9928 - loss: 0.0681
# Epoch 180/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9445 - loss: 0.1459
# Epoch 181/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0413
# Epoch 182/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9771 - loss: 0.0515
# Epoch 183/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9779 - loss: 0.1042
# Epoch 184/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9840 - loss: 0.0605
# Epoch 185/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0215
# Epoch 186/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0788
# Epoch 187/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9208 - loss: 0.1277
# Epoch 188/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0337
# Epoch 189/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.0724
# Epoch 190/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0330
# Epoch 191/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0295
# Epoch 192/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9928 - loss: 0.0382
# Epoch 193/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0450
# Epoch 194/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0267
# Epoch 195/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0148
# Epoch 196/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9927 - loss: 0.0562
# Epoch 197/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9675 - loss: 0.0663
# Epoch 198/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 199/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.0471
# Epoch 200/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0122
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import SGD
import random

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Load intents data
data_file = open('data.json').read()
intents = json.loads(data_file)

words = []
classes = []
documents = []
ignore_words = ['?', '!']

# Process intents
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lemmatize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)

# Save words and classes
pickle.dump(words, open('texts.pkl', 'wb'))
pickle.dump(classes, open('labels.pkl', 'wb'))

# Create training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# Debugging print to check lengths of input and output vectors
for t in training:
    print(f'Input vector length: {len(t[0])}, Output vector length: {len(t[1])}')

# Shuffle the training data
random.shuffle(training)

# Ensure all lists in training data have consistent lengths before converting to numpy arrays
train_x = []
train_y = []
for t in training:
    train_x.append(t[0])
    train_y.append(t[1])

# Convert lists to numpy arrays
train_x = np.array(train_x, dtype=np.float32)
train_y = np.array(train_y, dtype=np.float32)

print("Training data created")

# Debugging print to check shapes of train_x and train_y
print(f'train_x shape: {train_x.shape}')
print(f'train_y shape: {train_y.shape}')

# Create the model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile the model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Fit and save the model
hist = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)
model.save('model.h5')

print("model created")
# Out:
# 79 documents
# 19 classes ['chemical_engineering', 'civil_engineering', 'data_preprocessing', 'data_science_overview', 'data_science_tools', 'data_visualization', 'deep_learning', 'electrical_engineering', 'engineering_calculations', 'engineering_disciplines', 'engineering_software_tools', 'goodbye', 'greeting', 'machine_learning', 'mechanical_engineering', 'noanswer', 'software_engineering', 'statistics', 'thanks']
# 95 unique lemmatized words ["'re", 'a', 'about', 'analysis', 'application', 'appreciate', 'are', 'basic', 'branch', 'bye', 'calculation', 'can', 'chemical', 'civil', 'clarify', 'cleaning', 'common', 'concept', 'data', 'deep', 'design', 'different', 'discipline', 'do', 'doe', 'electrical', 'engineer', 'engineering', 'example', 'explain', 'farewell', 'field', 'for', 'formula', 'further', 'goodbye', 'greeting', 'hello', 'helpful', 'hey', 'hi', 'how', 'i', 'importance', 'important', 'in', 'involve', 'is', 'it', 'later', 'learning', 'lot', 'machine', 'main', 'me', 'mean', 'mechanical', 'method', "n't", 'not', 'of', 'overview', 'perform', 'popular', 'practice', 'preprocessing', 'problem', 'process', 'project', 'role', 'science', 'scientist', 'see', 'software', 'statistic', 'statistical', 'step', 'sure', 'talk', 'technique', 'tell', 'thank', 'thanks', 'the', 'there', 'to', 'tool', 'type', 'understand', 'used', 'v', 'visualization', 'what', 'why', 'you']
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Input vector length: 95, Output vector length: 19
# Training data created
# train_x shape: (79, 95)
# train_y shape: (79, 19)
# Epoch 1/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0263 - loss: 2.9556
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0759 - loss: 2.8997
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0865 - loss: 2.8591
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0826 - loss: 2.8528
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2186 - loss: 2.6553
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1651 - loss: 2.6387
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3680 - loss: 2.4577
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3904 - loss: 2.3207
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4182 - loss: 2.2722
# Epoch 10/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5838 - loss: 1.8340
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4066 - loss: 2.0408
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3450 - loss: 2.0660
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4656 - loss: 1.8124
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4926 - loss: 1.6138
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5906 - loss: 1.5744
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6691 - loss: 1.2204
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5237 - loss: 1.4456
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6466 - loss: 1.2971
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7887 - loss: 0.8948
# Epoch 20/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8493 - loss: 0.7431
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6281 - loss: 1.0594
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7093 - loss: 1.0610
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6883 - loss: 0.8325
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7901 - loss: 0.6352
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8774 - loss: 0.5113
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7773 - loss: 0.6958
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8634 - loss: 0.5843
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8270 - loss: 0.6261
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8099 - loss: 0.5985
# Epoch 30/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7308 - loss: 0.8498
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8388 - loss: 0.4663
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9434 - loss: 0.3528
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8827 - loss: 0.4900
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8789 - loss: 0.4588
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8350 - loss: 0.6946
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7889 - loss: 0.6156
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8407 - loss: 0.3967
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9378 - loss: 0.4079
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9416 - loss: 0.2694
# Epoch 40/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9378 - loss: 0.3038
# Epoch 41/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9222 - loss: 0.4124
# Epoch 42/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9158 - loss: 0.4296
# Epoch 43/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8881 - loss: 0.4045
# Epoch 44/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9163 - loss: 0.2576
# Epoch 45/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9103 - loss: 0.3054
# Epoch 46/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9385 - loss: 0.2665
# Epoch 47/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9443 - loss: 0.3652
# Epoch 48/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9066 - loss: 0.2997
# Epoch 49/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.2294
# Epoch 50/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9775 - loss: 0.2329
# Epoch 51/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9701 - loss: 0.1764
# Epoch 52/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9114 - loss: 0.3017
# Epoch 53/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9279 - loss: 0.2151
# Epoch 54/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8994 - loss: 0.3150
# Epoch 55/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.2081
# Epoch 56/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.1607
# Epoch 57/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8785 - loss: 0.2561
# Epoch 58/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9224 - loss: 0.2340
# Epoch 59/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9590 - loss: 0.1532
# Epoch 60/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9576 - loss: 0.1267
# Epoch 61/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8882 - loss: 0.3409
# Epoch 62/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9806 - loss: 0.1141
# Epoch 63/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9790 - loss: 0.1716
# Epoch 64/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9510 - loss: 0.1562
# Epoch 65/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9366 - loss: 0.1723
# Epoch 66/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.1670
# Epoch 67/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9487 - loss: 0.2118
# Epoch 68/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9705 - loss: 0.2141
# Epoch 69/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.1419
# Epoch 70/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9457 - loss: 0.1898
# Epoch 71/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9465 - loss: 0.1127
# Epoch 72/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9950 - loss: 0.1257
# Epoch 73/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9158 - loss: 0.2210
# Epoch 74/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9595 - loss: 0.1179
# Epoch 75/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9641 - loss: 0.1155
# Epoch 76/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9425 - loss: 0.1724
# Epoch 77/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0835
# Epoch 78/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9750 - loss: 0.1424
# Epoch 79/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.1096
# Epoch 80/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9727 - loss: 0.0958
# Epoch 81/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9680 - loss: 0.1888
# Epoch 82/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0548
# Epoch 83/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9443 - loss: 0.1634
# Epoch 84/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9489 - loss: 0.1495
# Epoch 85/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9852 - loss: 0.0970
# Epoch 86/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9540 - loss: 0.1424
# Epoch 87/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9464 - loss: 0.1680
# Epoch 88/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9746 - loss: 0.1431
# Epoch 89/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9887 - loss: 0.0679
# Epoch 90/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8913 - loss: 0.1979
# Epoch 91/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9195 - loss: 0.2123
# Epoch 92/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9771 - loss: 0.0524
# Epoch 93/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9454 - loss: 0.1251
# Epoch 94/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.0905
# Epoch 95/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9771 - loss: 0.1028
# Epoch 96/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.0403
# Epoch 97/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9843 - loss: 0.0838
# Epoch 98/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9017 - loss: 0.2126
# Epoch 99/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9598 - loss: 0.1379
# Epoch 100/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9375 - loss: 0.1133
# Epoch 101/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9553 - loss: 0.1056
# Epoch 102/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9534 - loss: 0.1340
# Epoch 103/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.1038
# Epoch 104/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9222 - loss: 0.2782
# Epoch 105/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9869 - loss: 0.0723
# Epoch 106/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9823 - loss: 0.0649
# Epoch 107/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.0703
# Epoch 108/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0380
# Epoch 109/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9764 - loss: 0.0690
# Epoch 110/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9688 - loss: 0.1237
# Epoch 111/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0392
# Epoch 112/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.0768
# Epoch 113/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9460 - loss: 0.0881
# Epoch 114/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0500
# Epoch 115/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.0509
# Epoch 116/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9756 - loss: 0.1014
# Epoch 117/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9977 - loss: 0.0809
# Epoch 118/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9639 - loss: 0.0965
# Epoch 119/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.0400
# Epoch 120/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0685
# Epoch 121/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9840 - loss: 0.1165
# Epoch 122/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0939
# Epoch 123/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9712 - loss: 0.0758
# Epoch 124/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9464 - loss: 0.1010
# Epoch 125/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9662 - loss: 0.0661
# Epoch 126/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9519 - loss: 0.0948
# Epoch 127/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0219
# Epoch 128/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0364
# Epoch 129/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9571 - loss: 0.0993
# Epoch 130/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9493 - loss: 0.1051
# Epoch 131/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0735
# Epoch 132/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9841 - loss: 0.0484
# Epoch 133/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9969 - loss: 0.0227
# Epoch 134/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0520
# Epoch 135/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9883 - loss: 0.0420
# Epoch 136/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9405 - loss: 0.1884
# Epoch 137/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0737
# Epoch 138/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0363
# Epoch 139/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0273
# Epoch 140/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9810 - loss: 0.0787
# Epoch 141/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 142/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9654 - loss: 0.0912
# Epoch 143/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0195
# Epoch 144/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0321
# Epoch 145/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0354
# Epoch 146/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.1688
# Epoch 147/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9746 - loss: 0.0934
# Epoch 148/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 149/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0153
# Epoch 150/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0315
# Epoch 151/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9595 - loss: 0.0880
# Epoch 152/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9567 - loss: 0.0620
# Epoch 153/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9810 - loss: 0.0335
# Epoch 154/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0320
# Epoch 155/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0308
# Epoch 156/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.1171
# Epoch 157/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9522 - loss: 0.1263
# Epoch 158/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9712 - loss: 0.0924
# Epoch 159/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 160/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.2128
# Epoch 161/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9415 - loss: 0.1279
# Epoch 162/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9683 - loss: 0.1149
# Epoch 163/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0378
# Epoch 164/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0388
# Epoch 165/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0473
# Epoch 166/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0349
# Epoch 167/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0446
# Epoch 168/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0877
# Epoch 169/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0893
# Epoch 170/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.0465
# Epoch 171/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 172/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9810 - loss: 0.0804
# Epoch 173/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0272
# Epoch 174/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9928 - loss: 0.0491
# Epoch 175/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0578
# Epoch 176/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.1164
# Epoch 177/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0384
# Epoch 178/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 179/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9788 - loss: 0.0463
# Epoch 180/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0475
# Epoch 181/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.0885
# Epoch 182/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.0290
# Epoch 183/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9710 - loss: 0.0679
# Epoch 184/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0457
# Epoch 185/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9810 - loss: 0.0516
# Epoch 186/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0228
# Epoch 187/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9854 - loss: 0.0722
# Epoch 188/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9759 - loss: 0.0798
# Epoch 189/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9771 - loss: 0.0819
# Epoch 190/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0346
# Epoch 191/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0473
# Epoch 192/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0790
# Epoch 193/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9841 - loss: 0.0575
# Epoch 194/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0267
# Epoch 195/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0636
# Epoch 196/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0226
# Epoch 197/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0296
# Epoch 198/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9960 - loss: 0.0215
# Epoch 199/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.0732
# Epoch 200/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0580
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import legacy as optimizers
import random

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Load intents data
data_file = open('data.json').read()
intents = json.loads(data_file)

words = []
classes = []
documents = []
ignore_words = ['?', '!']

# Process intents
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lemmatize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)

# Save words and classes
pickle.dump(words, open('texts.pkl', 'wb'))
pickle.dump(classes, open('labels.pkl', 'wb'))

# Create training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# Debugging print to check lengths of input and output vectors
for t in training:
    print(f'Input vector length: {len(t[0])}, Output vector length: {len(t[1])}')

# Shuffle the training data
random.shuffle(training)

# Ensure all lists in training data have consistent lengths before converting to numpy arrays
train_x = []
train_y = []
for t in training:
    train_x.append(t[0])
    train_y.append(t[1])

# Convert lists to numpy arrays
train_x = np.array(train_x, dtype=np.float32)
train_y = np.array(train_y, dtype=np.float32)

print("Training data created")

# Debugging print to check shapes of train_x and train_y
print(f'train_x shape: {train_x.shape}')
print(f'train_y shape: {train_y.shape}')

# Create the model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile the model using the legacy optimizer
sgd = optimizers.SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Fit and save the model
hist = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)
model.save('model.h5')

print("model created")
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Input vector length: 88, Output vector length: 9
# Training data created
# train_x shape: (47, 88)
# train_y shape: (47, 9)
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Windows\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Windows\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 10/10 [==============================] - 1s 5ms/step - loss: 2.2561 - accuracy: 0.1489
# Epoch 2/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1995 - accuracy: 0.0213
# Epoch 3/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0677 - accuracy: 0.2340
# Epoch 4/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0460 - accuracy: 0.2979
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8874 - accuracy: 0.4255
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7585 - accuracy: 0.4681
# Epoch 7/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.7356 - accuracy: 0.4681
# Epoch 8/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.5000 - accuracy: 0.6596
# Epoch 9/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3792 - accuracy: 0.5957
# Epoch 10/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2431 - accuracy: 0.7021
# Epoch 11/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2285 - accuracy: 0.5745
# Epoch 12/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0496 - accuracy: 0.7660
# Epoch 13/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8396 - accuracy: 0.8511
# Epoch 14/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7401 - accuracy: 0.8511
# Epoch 15/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.7770 - accuracy: 0.7872
# Epoch 16/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7247 - accuracy: 0.8298
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6546 - accuracy: 0.7872
# Epoch 18/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7138 - accuracy: 0.7660
# Epoch 19/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.7234
# Epoch 20/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5184 - accuracy: 0.8723
# Epoch 21/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5839 - accuracy: 0.7872
# Epoch 22/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5027 - accuracy: 0.8723
# Epoch 23/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5155 - accuracy: 0.8511
# Epoch 24/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4052 - accuracy: 0.9149
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3279 - accuracy: 0.9362
# Epoch 26/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2974 - accuracy: 0.8723
# Epoch 27/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3175 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2218 - accuracy: 0.9574
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4492 - accuracy: 0.8723
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1167 - accuracy: 1.0000
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3561 - accuracy: 0.9149
# Epoch 32/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3156 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2526 - accuracy: 0.9574
# Epoch 34/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1809 - accuracy: 0.9574
# Epoch 35/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2147 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2628 - accuracy: 0.9149
# Epoch 37/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2657 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2455 - accuracy: 0.9362
# Epoch 39/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2679 - accuracy: 0.9149
# Epoch 40/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2019 - accuracy: 0.9149
# Epoch 41/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1340 - accuracy: 1.0000
# Epoch 42/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1401 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1782 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1233 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2270 - accuracy: 0.9362
# Epoch 46/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0889 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1359 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1804 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1254 - accuracy: 0.9787
# Epoch 50/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0998 - accuracy: 0.9574
# Epoch 52/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1503 - accuracy: 0.9574
# Epoch 53/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0758 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0582 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1067 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0534 - accuracy: 0.9787
# Epoch 58/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0998 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0807 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1058 - accuracy: 0.9574
# Epoch 61/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0789 - accuracy: 0.9574
# Epoch 62/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1209 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0971 - accuracy: 0.9574
# Epoch 66/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0855 - accuracy: 0.9574
# Epoch 68/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0551 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0938 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1048 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0721 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0611 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0886 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0822 - accuracy: 0.9574
# Epoch 79/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0743 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0638 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 0.9787
# Epoch 84/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0541 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0483 - accuracy: 0.9787
# Epoch 89/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0446 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1407 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0793 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0840 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0434 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0620 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1345 - accuracy: 0.9362
# Epoch 106/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0749 - accuracy: 0.9787
# Epoch 107/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0606 - accuracy: 0.9787
# Epoch 108/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0439 - accuracy: 0.9787
# Epoch 110/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0808 - accuracy: 0.9574
# Epoch 117/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0497 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1404 - accuracy: 0.9574
# Epoch 122/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0411 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0903 - accuracy: 0.9787
# Epoch 127/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0544 - accuracy: 0.9787
# Epoch 131/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0749 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0667 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1337 - accuracy: 0.9574
# Epoch 138/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0357 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0529 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0564 - accuracy: 0.9787
# Epoch 146/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0528 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0444 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0595 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1104 - accuracy: 0.9574
# Epoch 177/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1257 - accuracy: 0.9574
# Epoch 178/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0529 - accuracy: 0.9787
# Epoch 185/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1223 - accuracy: 0.9787
# Epoch 189/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0666 - accuracy: 0.9787
# Epoch 190/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9787
# Epoch 195/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 0.9787
# Epoch 196/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9787
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 1.0000
# model created
# C:\Users\Windows\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
